# %% [markdown]
# # Energetics of the EN4 dataset
#
# Aim: The main aim of this analysis is to investigate how the excess of energy taken up by the oceans affect the heat versus the APE

# %%
import numpy as np
import numpy.ma as ma
import gsw
from gsw_gammat_analytic_CT_exact import *
from gsw_gammat_analytic_CT_fast import *
from gsw_gammat_analytic_CT import *
import time
import os
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import netCDF4 as nc4
import seaborn as sns
sns.set_context('paper')
palette = sns.color_palette("gnuplot", 3)
sns.set_theme(context='paper', style='dark', palette=palette,rc={'xtick.bottom': True,'ytick.left': True})

# %%
# Define analytical Lorenz reference density profile
# --------------------------------------------------
# Set values of coefficients
# --------------------------------------------------
a = 4.56016575
b = -1.24898501
c = 0.00439778209
d = 1030.99373
e = 8.32218903 

# Define gravity 
grav = 9.81

# Define analytical expressions for reference density and pressure
# ----------------------------------------------------------------
rhor = lambda z: a/(b+1)*(z+e)**(b+1) + c*z + d  ## This analytical density profile fitted on the WOCE dataset.
pr = lambda z: grav * (a/((b+1)*(b+2))*((z+e)**(b+2)) + c/2.*z**2 + d*z - a/((b+1)*(b+2))*e**(b+2))/1e4

filtIO = np.load('IO_filter.npy', allow_pickle = True)
filtPO = np.load('PO_filter.npy', allow_pickle = True)

# %%
# Locate the data and define rules for constructing data file names
# datadir = 'C:\Users\Linne\Documents\Github\APE-Estimates\Data'
# datadir = '/Users/remitailleux/Documents/DATASETS/EN4_DATA'
rootname = 'EN.4.2.2.f.analysis.g10.'

# Open a random file to extract relevant information and put the info into 'data' 
data = xr.open_dataset(f'Data/{rootname}195001.nc')
# fields = nc4.Dataset(f'{datadir}/{1950}/{rootname}195001.nc')


# Upload depth bounds and compute layer thickness
ZB = data.depth_bnds.to_numpy().squeeze() 
# ZB = fields.variables['depth_bnds'][:]
e3t = ZB[:,1] - ZB[:,0]
print(e3t.shape)
print(e3t) 

# Upldate longitude, latitude, and depths of temperature points
lon1D = data.lon.to_numpy()
# lon1D = fields.variables['lon'][:]
npi = len(lon1D)
lat1D = data.lat.to_numpy()
# lat1D = fields.variables['lat'][:]
npj = len(lat1D) 
z1D = data.depth.to_numpy() 
# z1D = fields.variables['depth'][:]
npk = len(z1D) 
print([npk,npj,npi])

# load practical salinity, primarily to get the mask
SP = data.salinity.to_masked_array().squeeze()

# Define 3D version of depths and compute the reference pressure
z3d = np.zeros([npk,npj,npi]) 
for k in range(0,npk):
    z3d[k, :, :] = z1D[k] 
prz = pr(z3d) 

# Compare horizontal area for each elements
ra = 6.371e6
dx = ra*(lon1D[1]-lon1D[0])*np.pi/180
print(f'length of dx={dx}')

#area = np.empty((npi,npj)) 
#area[:] = ra*dx*(np.sin((lat1D[:]+0.5)*np.pi/180) - np.sin((lat1D[:]-0.5)*np.pi/180))
#print(area.shape) 
#area = np.transpose(area) 
#print(area.shape) 

area = ra*dx*(np.sin((lat1D[:]+0.5)*np.pi/180) - np.sin((lat1D[:]-0.5)*np.pi/180))*np.ones(npi)[:,np.newaxis]
print(area.shape)
print(np.sum(area))

# Compute volume
dV = area.T*e3t[:, np.newaxis, np.newaxis]
print(np.sum(dV)) 

V_ijk = ma.array(dV,mask = SP.mask)
print(ma.sum(V_ijk))
V_total = ma.sum(V_ijk)
weights = V_ijk/V_total
print([V_total,ma.sum(weights)])

print(weights.shape)

# Define cp0
cp0 = gsw.energy.enthalpy(35.,20.,0.)/20.
print([cp0,3991.86795711963])
# Out:
# (42,)
# [ 10.0475    10.068301  10.0982    10.1413    10.2033    10.292297
#   10.420204  10.604195  10.868401  11.247604  11.791199  12.569702
#   13.682297  15.267395  17.516998  20.690811  25.132095  31.276794
#   39.645218  50.8013    65.25928   83.32501  104.900696 129.3208
#  155.3393   181.33575  205.69604  227.18677  245.15869  259.526
#  270.6034   278.90747  285.0017   289.40527  292.5515   294.78076
#  296.3518   297.45386  298.2256   298.76416  299.13965  299.40137 ]
# [42, 173, 360]
# length of dx=111194.92664455873
# (360, 173)
# 508415367427200.0
# 2.7962845208496005e+18
# 1.5142117733078182e+18
# [1.5142117733078182e+18, 1.0]
# (42, 173, 360)
# [3991.86795711963, 3991.86795711963]

# %% [markdown]
# # Temporal Loop

# %%
# Define month strings
months = ['01','02','03','04','05','06','07','08','09','10','11','12']

# Define starting and end year
start_year = 1960
end_year = 2020 
npoints = (end_year-start_year + 1)*12
ncounter = 0

CT_mean_time_series = np.zeros(npoints)
CT_IO_mean_time_series = np.zeros(npoints)
CT_PO_mean_time_series = np.zeros(npoints)

PT_mean_time_series = np.zeros(npoints)
PT_IO_mean_time_series = np.zeros(npoints)
PT_PO_mean_time_series = np.zeros(npoints)

CTR_mean_time_series = np.zeros(npoints)
CTR_IO_mean_time_series = np.zeros(npoints)
CTR_PO_mean_time_series = np.zeros(npoints)

APE_mean_time_series = np.zeros(npoints)
APE_IO_mean_time_series = np.zeros(npoints)
APE_PO_mean_time_series = np.zeros(npoints)

APE_bis_time_series = np.zeros(npoints) 
APE_negative_time_series = np.zeros(npoints)

# Start of temporal loop 

for year in range(start_year,end_year+1):
    decade = (year//10)*10  
    for month in months:
        print(ncounter) 
        
        start = time.time()
        
        # define filename and open the data set using xarray, storing the result into 'data' 
        filename = f'Data/{rootname}{year}{month}.nc'
        print(filename)
        data = xr.open_dataset(filename)
        # fields = nc4.Dataset(filename)
        
        # load practical salinity
        SP = data.salinity.to_masked_array().squeeze()
        # SP = fields.variables['salinity'][0,:]
        # load potential temperature and convert it from Kelvins to Celsius
        PT = data.temperature.to_masked_array().squeeze() - 273.15
        # PT = fields.variables['temperature'][0,:] - 273.15
        
        #calculating reference salinity from practical salinity
        SR = gsw.conversions.SR_from_SP(SP)
        #calculating conservative temperature from SR and PT  
        CT = gsw.conversions.CT_from_pt(SR, PT)
            
        # calculating zref, pref
        gammat, zref, pref, sigref = gsw_gammat_analytic_CT_fast(SR, CT)
        
        # calculating enthalpies
        href = gsw.energy.enthalpy(SR, CT, pref)
        h = gsw.energy.enthalpy(SR, CT, prz)
   
        # Calculate reference CT and APE density 
        CTR = (href - grav*zref)/cp0 
        APE = h - href - grav*(z3d-zref) 
        
        # Copy the APE array to test the impact of remaining negative APE values 
        APE_bis = np.ma.copy(APE)
        APE_bis = np.ma.where(APE_bis < 0,0, APE_bis) 
        
        # mean temperature
        weighted_CT = CT*weights
        CT_mean_time_series[ncounter] = ma.sum(weighted_CT)
        CT_IO_mean_time_series[ncounter] = ma.sum(weighted_CT*filtIO)
        CT_PO_mean_time_series[ncounter] = ma.sum(weighted_CT*filtPO)
        
        weighted_PT = PT*weights
        PT_mean_time_series[ncounter] = ma.sum(weighted_PT)
        PT_IO_mean_time_series[ncounter] = ma.sum(weighted_PT*filtIO)
        PT_PO_mean_time_series[ncounter] = ma.sum(weighted_PT*filtPO)

        weighted_CTR = CTR*weights
        CTR_mean_time_series[ncounter] = ma.sum(weighted_CTR)
        CTR_IO_mean_time_series[ncounter] = ma.sum(weighted_CTR*filtIO)
        CTR_PO_mean_time_series[ncounter] = ma.sum(weighted_CTR*filtPO)  
        
        weighted_APE = APE*weights
        APE_mean_time_series[ncounter] = ma.sum(weighted_APE)
        APE_IO_mean_time_series[ncounter] = ma.sum(weighted_APE*filtIO)
        APE_PO_mean_time_series[ncounter] = ma.sum(weighted_APE*filtPO)   
        
        mean_APE_bis = ma.sum(APE_bis*weights)
        APE_bis_time_series[ncounter] = mean_APE_bis 
        
        APE_negative_time_series[ncounter] = np.sum(APE<0) 
        print(APE_negative_time_series[ncounter]) 
        
        end = time.time() 
        print(f'time iteration = {end-start}')
#         print(f'mean temperature = {mean_CT}')
        ncounter = ncounter + 1
# Out:
# 0
# Data/EN.4.2.2.f.analysis.g10.196001.nc
# 1.0
# time iteration = 7.544267654418945
# 1
# Data/EN.4.2.2.f.analysis.g10.196002.nc
# 1.0
# time iteration = 7.6530702114105225
# 2
# Data/EN.4.2.2.f.analysis.g10.196003.nc
# 5.0
# time iteration = 7.120942115783691
# 3
# Data/EN.4.2.2.f.analysis.g10.196004.nc
# 2.0
# time iteration = 6.965559720993042
# 4
# Data/EN.4.2.2.f.analysis.g10.196005.nc
# 1.0
# time iteration = 7.185129165649414
# 5
# Data/EN.4.2.2.f.analysis.g10.196006.nc
# 3.0
# time iteration = 7.079342365264893
# 6
# Data/EN.4.2.2.f.analysis.g10.196007.nc
# 0.0
# time iteration = 6.567098379135132
# 7
# Data/EN.4.2.2.f.analysis.g10.196008.nc
# 2.0
# time iteration = 6.577303409576416
# 8
# Data/EN.4.2.2.f.analysis.g10.196009.nc
# 2.0
# time iteration = 6.583395957946777
# 9
# Data/EN.4.2.2.f.analysis.g10.196010.nc
# 0.0
# time iteration = 6.642534971237183
# 10
# Data/EN.4.2.2.f.analysis.g10.196011.nc
# 3.0
# time iteration = 6.8099143505096436
# 11
# Data/EN.4.2.2.f.analysis.g10.196012.nc
# 2.0
# time iteration = 6.720717430114746
# 12
# Data/EN.4.2.2.f.analysis.g10.196101.nc
# 1.0
# time iteration = 6.669605731964111
# 13
# Data/EN.4.2.2.f.analysis.g10.196102.nc
# 3.0
# time iteration = 6.609806060791016
# 14
# Data/EN.4.2.2.f.analysis.g10.196103.nc
# 1.0
# time iteration = 6.9474828243255615
# 15
# Data/EN.4.2.2.f.analysis.g10.196104.nc
# 2.0
# time iteration = 6.5645647048950195
# 16
# Data/EN.4.2.2.f.analysis.g10.196105.nc
# 1.0
# time iteration = 6.581301689147949
# 17
# Data/EN.4.2.2.f.analysis.g10.196106.nc
# 3.0
# time iteration = 6.547688245773315
# 18
# Data/EN.4.2.2.f.analysis.g10.196107.nc
# 4.0
# time iteration = 6.573293209075928
# 19
# Data/EN.4.2.2.f.analysis.g10.196108.nc
# 1.0
# time iteration = 6.520241022109985
# 20
# Data/EN.4.2.2.f.analysis.g10.196109.nc
# 2.0
# time iteration = 6.527491807937622
# 21
# Data/EN.4.2.2.f.analysis.g10.196110.nc
# 1.0
# time iteration = 6.525240421295166
# 22
# Data/EN.4.2.2.f.analysis.g10.196111.nc
# 4.0
# time iteration = 6.528289079666138
# 23
# Data/EN.4.2.2.f.analysis.g10.196112.nc
# 0.0
# time iteration = 6.781692743301392
# 24
# Data/EN.4.2.2.f.analysis.g10.196201.nc
# 3.0
# time iteration = 6.638395071029663
# 25
# Data/EN.4.2.2.f.analysis.g10.196202.nc
# 1.0
# time iteration = 6.609147310256958
# 26
# Data/EN.4.2.2.f.analysis.g10.196203.nc
# 0.0
# time iteration = 6.706894159317017
# 27
# Data/EN.4.2.2.f.analysis.g10.196204.nc
# 1.0
# time iteration = 6.556923866271973
# 28
# Data/EN.4.2.2.f.analysis.g10.196205.nc
# 2.0
# time iteration = 6.680680274963379
# 29
# Data/EN.4.2.2.f.analysis.g10.196206.nc
# 1.0
# time iteration = 6.7117743492126465
# 30
# Data/EN.4.2.2.f.analysis.g10.196207.nc
# 1.0
# time iteration = 6.697972059249878
# 31
# Data/EN.4.2.2.f.analysis.g10.196208.nc
# 0.0
# time iteration = 6.537487506866455
# 32
# Data/EN.4.2.2.f.analysis.g10.196209.nc
# 1.0
# time iteration = 6.99614143371582
# 33
# Data/EN.4.2.2.f.analysis.g10.196210.nc
# 0.0
# time iteration = 6.504863023757935
# 34
# Data/EN.4.2.2.f.analysis.g10.196211.nc
# 1.0
# time iteration = 6.647717475891113
# 35
# Data/EN.4.2.2.f.analysis.g10.196212.nc
# 0.0
# time iteration = 6.574722051620483
# 36
# Data/EN.4.2.2.f.analysis.g10.196301.nc
# 1.0
# time iteration = 6.607926607131958
# 37
# Data/EN.4.2.2.f.analysis.g10.196302.nc
# 0.0
# time iteration = 6.496670484542847
# 38
# Data/EN.4.2.2.f.analysis.g10.196303.nc
# 0.0
# time iteration = 6.566032648086548
# 39
# Data/EN.4.2.2.f.analysis.g10.196304.nc
# 0.0
# time iteration = 6.585548400878906
# 40
# Data/EN.4.2.2.f.analysis.g10.196305.nc
# 1.0
# time iteration = 6.5337183475494385
# 41
# Data/EN.4.2.2.f.analysis.g10.196306.nc
# 1.0
# time iteration = 6.935798168182373
# 42
# Data/EN.4.2.2.f.analysis.g10.196307.nc
# 3.0
# time iteration = 6.54237961769104
# 43
# Data/EN.4.2.2.f.analysis.g10.196308.nc
# 1.0
# time iteration = 6.50083065032959
# 44
# Data/EN.4.2.2.f.analysis.g10.196309.nc
# 5.0
# time iteration = 6.704235553741455
# 45
# Data/EN.4.2.2.f.analysis.g10.196310.nc
# 2.0
# time iteration = 6.559513092041016
# 46
# Data/EN.4.2.2.f.analysis.g10.196311.nc
# 1.0
# time iteration = 6.539590835571289
# 47
# Data/EN.4.2.2.f.analysis.g10.196312.nc
# 2.0
# time iteration = 6.78725004196167
# 48
# Data/EN.4.2.2.f.analysis.g10.196401.nc
# 3.0
# time iteration = 7.038284063339233
# 49
# Data/EN.4.2.2.f.analysis.g10.196402.nc
# 1.0
# time iteration = 6.748429775238037
# 50
# Data/EN.4.2.2.f.analysis.g10.196403.nc
# 3.0
# time iteration = 6.912553787231445
# 51
# Data/EN.4.2.2.f.analysis.g10.196404.nc
# 4.0
# time iteration = 6.957460165023804
# 52
# Data/EN.4.2.2.f.analysis.g10.196405.nc
# 2.0
# time iteration = 6.688289642333984
# 53
# Data/EN.4.2.2.f.analysis.g10.196406.nc
# 0.0
# time iteration = 6.625853538513184
# 54
# Data/EN.4.2.2.f.analysis.g10.196407.nc
# 2.0
# time iteration = 6.743743896484375
# 55
# Data/EN.4.2.2.f.analysis.g10.196408.nc
# 2.0
# time iteration = 6.657171010971069
# 56
# Data/EN.4.2.2.f.analysis.g10.196409.nc
# 1.0
# time iteration = 6.603670597076416
# 57
# Data/EN.4.2.2.f.analysis.g10.196410.nc
# 1.0
# time iteration = 6.567622900009155
# 58
# Data/EN.4.2.2.f.analysis.g10.196411.nc
# 1.0
# time iteration = 6.55168890953064
# 59
# Data/EN.4.2.2.f.analysis.g10.196412.nc
# 2.0
# time iteration = 6.8140928745269775
# 60
# Data/EN.4.2.2.f.analysis.g10.196501.nc
# 2.0
# time iteration = 6.554841041564941
# 61
# Data/EN.4.2.2.f.analysis.g10.196502.nc
# 1.0
# time iteration = 6.523191213607788
# 62
# Data/EN.4.2.2.f.analysis.g10.196503.nc
# 1.0
# time iteration = 6.5811378955841064
# 63
# Data/EN.4.2.2.f.analysis.g10.196504.nc
# 4.0
# time iteration = 6.518126726150513
# 64
# Data/EN.4.2.2.f.analysis.g10.196505.nc
# 2.0
# time iteration = 6.535573720932007
# 65
# Data/EN.4.2.2.f.analysis.g10.196506.nc
# 1.0
# time iteration = 6.543407201766968
# 66
# Data/EN.4.2.2.f.analysis.g10.196507.nc
# 2.0
# time iteration = 6.52738881111145
# 67
# Data/EN.4.2.2.f.analysis.g10.196508.nc
# 2.0
# time iteration = 6.660552978515625
# 68
# Data/EN.4.2.2.f.analysis.g10.196509.nc
# 2.0
# time iteration = 7.039751291275024
# 69
# Data/EN.4.2.2.f.analysis.g10.196510.nc
# 2.0
# time iteration = 6.533601760864258
# 70
# Data/EN.4.2.2.f.analysis.g10.196511.nc
# 1.0
# time iteration = 6.57873272895813
# 71
# Data/EN.4.2.2.f.analysis.g10.196512.nc
# 1.0
# time iteration = 6.5899879932403564
# 72
# Data/EN.4.2.2.f.analysis.g10.196601.nc
# 0.0
# time iteration = 6.593190670013428
# 73
# Data/EN.4.2.2.f.analysis.g10.196602.nc
# 2.0
# time iteration = 6.6873695850372314
# 74
# Data/EN.4.2.2.f.analysis.g10.196603.nc
# 1.0
# time iteration = 6.620331764221191
# 75
# Data/EN.4.2.2.f.analysis.g10.196604.nc
# 3.0
# time iteration = 6.730688095092773
# 76
# Data/EN.4.2.2.f.analysis.g10.196605.nc
# 0.0
# time iteration = 6.732043504714966
# 77
# Data/EN.4.2.2.f.analysis.g10.196606.nc
# 1.0
# time iteration = 6.963070392608643
# 78
# Data/EN.4.2.2.f.analysis.g10.196607.nc
# 1.0
# time iteration = 6.537707090377808
# 79
# Data/EN.4.2.2.f.analysis.g10.196608.nc
# 0.0
# time iteration = 6.652041435241699
# 80
# Data/EN.4.2.2.f.analysis.g10.196609.nc
# 1.0
# time iteration = 6.5722739696502686
# 81
# Data/EN.4.2.2.f.analysis.g10.196610.nc
# 0.0
# time iteration = 6.528381586074829
# 82
# Data/EN.4.2.2.f.analysis.g10.196611.nc
# 3.0
# time iteration = 6.811382532119751
# 83
# Data/EN.4.2.2.f.analysis.g10.196612.nc
# 0.0
# time iteration = 6.510461807250977
# 84
# Data/EN.4.2.2.f.analysis.g10.196701.nc
# 1.0
# time iteration = 6.534848690032959
# 85
# Data/EN.4.2.2.f.analysis.g10.196702.nc
# 3.0
# time iteration = 6.668250322341919
# 86
# Data/EN.4.2.2.f.analysis.g10.196703.nc
# 1.0
# time iteration = 6.980216026306152
# 87
# Data/EN.4.2.2.f.analysis.g10.196704.nc
# 1.0
# time iteration = 6.568361759185791
# 88
# Data/EN.4.2.2.f.analysis.g10.196705.nc
# 1.0
# time iteration = 6.664102077484131
# 89
# Data/EN.4.2.2.f.analysis.g10.196706.nc
# 0.0
# time iteration = 6.55376935005188
# 90
# Data/EN.4.2.2.f.analysis.g10.196707.nc
# 3.0
# time iteration = 6.841654539108276
# 91
# Data/EN.4.2.2.f.analysis.g10.196708.nc
# 2.0
# time iteration = 6.98968243598938
# 92
# Data/EN.4.2.2.f.analysis.g10.196709.nc
# 3.0
# time iteration = 7.429593563079834
# 93
# Data/EN.4.2.2.f.analysis.g10.196710.nc
# 2.0
# time iteration = 7.031063795089722
# 94
# Data/EN.4.2.2.f.analysis.g10.196711.nc
# 4.0
# time iteration = 7.223871946334839
# 95
# Data/EN.4.2.2.f.analysis.g10.196712.nc
# 2.0
# time iteration = 6.86333155632019
# 96
# Data/EN.4.2.2.f.analysis.g10.196801.nc
# 1.0
# time iteration = 6.665200710296631
# 97
# Data/EN.4.2.2.f.analysis.g10.196802.nc
# 0.0
# time iteration = 6.655308961868286
# 98
# Data/EN.4.2.2.f.analysis.g10.196803.nc
# 2.0
# time iteration = 6.677334785461426
# 99
# Data/EN.4.2.2.f.analysis.g10.196804.nc
# 4.0
# time iteration = 6.633439779281616
# 100
# Data/EN.4.2.2.f.analysis.g10.196805.nc
# 1.0
# time iteration = 6.659015655517578
# 101
# Data/EN.4.2.2.f.analysis.g10.196806.nc
# 1.0
# time iteration = 6.6161274909973145
# 102
# Data/EN.4.2.2.f.analysis.g10.196807.nc
# 1.0
# time iteration = 7.024564743041992
# 103
# Data/EN.4.2.2.f.analysis.g10.196808.nc
# 3.0
# time iteration = 6.823008060455322
# 104
# Data/EN.4.2.2.f.analysis.g10.196809.nc
# 0.0
# time iteration = 6.7030723094940186
# 105
# Data/EN.4.2.2.f.analysis.g10.196810.nc
# 1.0
# time iteration = 6.548150539398193
# 106
# Data/EN.4.2.2.f.analysis.g10.196811.nc
# 1.0
# time iteration = 6.555384874343872
# 107
# Data/EN.4.2.2.f.analysis.g10.196812.nc
# 3.0
# time iteration = 6.5481696128845215
# 108
# Data/EN.4.2.2.f.analysis.g10.196901.nc
# 1.0
# time iteration = 6.5795512199401855
# 109
# Data/EN.4.2.2.f.analysis.g10.196902.nc
# 0.0
# time iteration = 6.666961669921875
# 110
# Data/EN.4.2.2.f.analysis.g10.196903.nc
# 3.0
# time iteration = 6.568358659744263
# 111
# Data/EN.4.2.2.f.analysis.g10.196904.nc
# 2.0
# time iteration = 6.577198028564453
# 112
# Data/EN.4.2.2.f.analysis.g10.196905.nc
# 1.0
# time iteration = 6.613324880599976
# 113
# Data/EN.4.2.2.f.analysis.g10.196906.nc
# 4.0
# time iteration = 6.760495185852051
# 114
# Data/EN.4.2.2.f.analysis.g10.196907.nc
# 3.0
# time iteration = 6.554121255874634
# 115
# Data/EN.4.2.2.f.analysis.g10.196908.nc
# 2.0
# time iteration = 6.527590751647949
# 116
# Data/EN.4.2.2.f.analysis.g10.196909.nc
# 0.0
# time iteration = 6.613113880157471
# 117
# Data/EN.4.2.2.f.analysis.g10.196910.nc
# 1.0
# time iteration = 6.634778022766113
# 118
# Data/EN.4.2.2.f.analysis.g10.196911.nc
# 1.0
# time iteration = 6.589284420013428
# 119
# Data/EN.4.2.2.f.analysis.g10.196912.nc
# 3.0
# time iteration = 6.793084144592285
# 120
# Data/EN.4.2.2.f.analysis.g10.197001.nc
# 1.0
# time iteration = 6.874025821685791
# 121
# Data/EN.4.2.2.f.analysis.g10.197002.nc
# 3.0
# time iteration = 7.461007833480835
# 122
# Data/EN.4.2.2.f.analysis.g10.197003.nc
# 0.0
# time iteration = 6.775198936462402
# 123
# Data/EN.4.2.2.f.analysis.g10.197004.nc
# 1.0
# time iteration = 6.543953895568848
# 124
# Data/EN.4.2.2.f.analysis.g10.197005.nc
# 3.0
# time iteration = 6.998582363128662
# 125
# Data/EN.4.2.2.f.analysis.g10.197006.nc
# 2.0
# time iteration = 6.877190828323364
# 126
# Data/EN.4.2.2.f.analysis.g10.197007.nc
# 4.0
# time iteration = 6.589779376983643
# 127
# Data/EN.4.2.2.f.analysis.g10.197008.nc
# 1.0
# time iteration = 6.921632528305054
# 128
# Data/EN.4.2.2.f.analysis.g10.197009.nc
# 1.0
# time iteration = 7.012917518615723
# 129
# Data/EN.4.2.2.f.analysis.g10.197010.nc
# 0.0
# time iteration = 7.396257400512695
# 130
# Data/EN.4.2.2.f.analysis.g10.197011.nc
# 3.0
# time iteration = 7.774115800857544
# 131
# Data/EN.4.2.2.f.analysis.g10.197012.nc
# 0.0
# time iteration = 7.472988843917847
# 132
# Data/EN.4.2.2.f.analysis.g10.197101.nc
# 1.0
# time iteration = 7.64650559425354
# 133
# Data/EN.4.2.2.f.analysis.g10.197102.nc
# 2.0
# time iteration = 7.310009002685547
# 134
# Data/EN.4.2.2.f.analysis.g10.197103.nc
# 1.0
# time iteration = 7.770694017410278
# 135
# Data/EN.4.2.2.f.analysis.g10.197104.nc
# 0.0
# time iteration = 7.578506946563721
# 136
# Data/EN.4.2.2.f.analysis.g10.197105.nc
# 1.0
# time iteration = 6.566045522689819
# 137
# Data/EN.4.2.2.f.analysis.g10.197106.nc
# 2.0
# time iteration = 6.592172145843506
# 138
# Data/EN.4.2.2.f.analysis.g10.197107.nc
# 2.0
# time iteration = 6.7170515060424805
# 139
# Data/EN.4.2.2.f.analysis.g10.197108.nc
# 2.0
# time iteration = 6.706528663635254
# 140
# Data/EN.4.2.2.f.analysis.g10.197109.nc
# 0.0
# time iteration = 6.636199951171875
# 141
# Data/EN.4.2.2.f.analysis.g10.197110.nc
# 2.0
# time iteration = 6.55022931098938
# 142
# Data/EN.4.2.2.f.analysis.g10.197111.nc
# 2.0
# time iteration = 6.5659096240997314
# 143
# Data/EN.4.2.2.f.analysis.g10.197112.nc
# 3.0
# time iteration = 6.579461574554443
# 144
# Data/EN.4.2.2.f.analysis.g10.197201.nc
# 0.0
# time iteration = 6.5502519607543945
# 145
# Data/EN.4.2.2.f.analysis.g10.197202.nc
# 2.0
# time iteration = 6.559557914733887
# 146
# Data/EN.4.2.2.f.analysis.g10.197203.nc
# 0.0
# time iteration = 6.54928731918335
# 147
# Data/EN.4.2.2.f.analysis.g10.197204.nc
# 1.0
# time iteration = 6.766788721084595
# 148
# Data/EN.4.2.2.f.analysis.g10.197205.nc
# 3.0
# time iteration = 6.703325986862183
# 149
# Data/EN.4.2.2.f.analysis.g10.197206.nc
# 2.0
# time iteration = 6.565035581588745
# 150
# Data/EN.4.2.2.f.analysis.g10.197207.nc
# 2.0
# time iteration = 6.53965163230896
# 151
# Data/EN.4.2.2.f.analysis.g10.197208.nc
# 3.0
# time iteration = 6.569262266159058
# 152
# Data/EN.4.2.2.f.analysis.g10.197209.nc
# 0.0
# time iteration = 6.642909526824951
# 153
# Data/EN.4.2.2.f.analysis.g10.197210.nc
# 3.0
# time iteration = 6119.6299250125885
# 154
# Data/EN.4.2.2.f.analysis.g10.197211.nc
# 4.0
# time iteration = 8.217291116714478
# 155
# Data/EN.4.2.2.f.analysis.g10.197212.nc
# 1.0
# time iteration = 7.238206386566162
# 156
# Data/EN.4.2.2.f.analysis.g10.197301.nc
# 2.0
# time iteration = 7.222959995269775
# 157
# Data/EN.4.2.2.f.analysis.g10.197302.nc
# 2.0
# time iteration = 7.144874811172485
# 158
# Data/EN.4.2.2.f.analysis.g10.197303.nc
# 0.0
# time iteration = 7.248905181884766
# 159
# Data/EN.4.2.2.f.analysis.g10.197304.nc
# 1.0
# time iteration = 6.970124244689941
# 160
# Data/EN.4.2.2.f.analysis.g10.197305.nc
# 0.0
# time iteration = 6.615283250808716
# 161
# Data/EN.4.2.2.f.analysis.g10.197306.nc
# 1.0
# time iteration = 6.8139808177948
# 162
# Data/EN.4.2.2.f.analysis.g10.197307.nc
# 2.0
# time iteration = 6.324954271316528
# 163
# Data/EN.4.2.2.f.analysis.g10.197308.nc
# 2.0
# time iteration = 6.3542094230651855
# 164
# Data/EN.4.2.2.f.analysis.g10.197309.nc
# 0.0
# time iteration = 6.4089930057525635
# 165
# Data/EN.4.2.2.f.analysis.g10.197310.nc
# 2.0
# time iteration = 6.945921421051025
# 166
# Data/EN.4.2.2.f.analysis.g10.197311.nc
# 0.0
# time iteration = 6.343438386917114
# 167
# Data/EN.4.2.2.f.analysis.g10.197312.nc
# 1.0
# time iteration = 6.360241413116455
# 168
# Data/EN.4.2.2.f.analysis.g10.197401.nc
# 0.0
# time iteration = 6.319451570510864
# 169
# Data/EN.4.2.2.f.analysis.g10.197402.nc
# 1.0
# time iteration = 6.3384974002838135
# 170
# Data/EN.4.2.2.f.analysis.g10.197403.nc
# 1.0
# time iteration = 6.414228439331055
# 171
# Data/EN.4.2.2.f.analysis.g10.197404.nc
# 2.0
# time iteration = 6.3871965408325195
# 172
# Data/EN.4.2.2.f.analysis.g10.197405.nc
# 3.0
# time iteration = 6.309924602508545
# 173
# Data/EN.4.2.2.f.analysis.g10.197406.nc
# 0.0
# time iteration = 6.29073691368103
# 174
# Data/EN.4.2.2.f.analysis.g10.197407.nc
# 2.0
# time iteration = 7.768943548202515
# 175
# Data/EN.4.2.2.f.analysis.g10.197408.nc
# 0.0
# time iteration = 6.8605873584747314
# 176
# Data/EN.4.2.2.f.analysis.g10.197409.nc
# 1.0
# time iteration = 6.3295862674713135
# 177
# Data/EN.4.2.2.f.analysis.g10.197410.nc
# 0.0
# time iteration = 6.561516284942627
# 178
# Data/EN.4.2.2.f.analysis.g10.197411.nc
# 1.0
# time iteration = 6.497806787490845
# 179
# Data/EN.4.2.2.f.analysis.g10.197412.nc
# 1.0
# time iteration = 6.63889217376709
# 180
# Data/EN.4.2.2.f.analysis.g10.197501.nc
# 0.0
# time iteration = 8.356408596038818
# 181
# Data/EN.4.2.2.f.analysis.g10.197502.nc
# 1.0
# time iteration = 8.014326333999634
# 182
# Data/EN.4.2.2.f.analysis.g10.197503.nc
# 1.0
# time iteration = 6.672115802764893
# 183
# Data/EN.4.2.2.f.analysis.g10.197504.nc
# 1.0
# time iteration = 6.923435926437378
# 184
# Data/EN.4.2.2.f.analysis.g10.197505.nc
# 2.0
# time iteration = 6.318801641464233
# 185
# Data/EN.4.2.2.f.analysis.g10.197506.nc
# 1.0
# time iteration = 6.369945526123047
# 186
# Data/EN.4.2.2.f.analysis.g10.197507.nc
# 2.0
# time iteration = 6.360327959060669
# 187
# Data/EN.4.2.2.f.analysis.g10.197508.nc
# 1.0
# time iteration = 6.316405296325684
# 188
# Data/EN.4.2.2.f.analysis.g10.197509.nc
# 2.0
# time iteration = 6.483982801437378
# 189
# Data/EN.4.2.2.f.analysis.g10.197510.nc
# 1.0
# time iteration = 6.375793695449829
# 190
# Data/EN.4.2.2.f.analysis.g10.197511.nc
# 2.0
# time iteration = 6.739309549331665
# 191
# Data/EN.4.2.2.f.analysis.g10.197512.nc
# 4.0
# time iteration = 6.944913148880005
# 192
# Data/EN.4.2.2.f.analysis.g10.197601.nc
# 1.0
# time iteration = 8.756277799606323
# 193
# Data/EN.4.2.2.f.analysis.g10.197602.nc
# 0.0
# time iteration = 8.186494588851929
# 194
# Data/EN.4.2.2.f.analysis.g10.197603.nc
# 0.0
# time iteration = 8.242406368255615
# 195
# Data/EN.4.2.2.f.analysis.g10.197604.nc
# 2.0
# time iteration = 8.422464847564697
# 196
# Data/EN.4.2.2.f.analysis.g10.197605.nc
# 0.0
# time iteration = 8.585099697113037
# 197
# Data/EN.4.2.2.f.analysis.g10.197606.nc
# 2.0
# time iteration = 8.311952590942383
# 198
# Data/EN.4.2.2.f.analysis.g10.197607.nc
# 2.0
# time iteration = 8.162001609802246
# 199
# Data/EN.4.2.2.f.analysis.g10.197608.nc
# 0.0
# time iteration = 8.408973455429077
# 200
# Data/EN.4.2.2.f.analysis.g10.197609.nc
# 1.0
# time iteration = 8.254040718078613
# 201
# Data/EN.4.2.2.f.analysis.g10.197610.nc
# 2.0
# time iteration = 8.111535549163818
# 202
# Data/EN.4.2.2.f.analysis.g10.197611.nc
# 1.0
# time iteration = 8.336337089538574
# 203
# Data/EN.4.2.2.f.analysis.g10.197612.nc
# 2.0
# time iteration = 8.364134311676025
# 204
# Data/EN.4.2.2.f.analysis.g10.197701.nc
# 2.0
# time iteration = 8.4973464012146
# 205
# Data/EN.4.2.2.f.analysis.g10.197702.nc
# 1.0
# time iteration = 8.424832820892334
# 206
# Data/EN.4.2.2.f.analysis.g10.197703.nc
# 1.0
# time iteration = 8.207581281661987
# 207
# Data/EN.4.2.2.f.analysis.g10.197704.nc
# 2.0
# time iteration = 8.443331718444824
# 208
# Data/EN.4.2.2.f.analysis.g10.197705.nc
# 0.0
# time iteration = 8.308227062225342
# 209
# Data/EN.4.2.2.f.analysis.g10.197706.nc
# 0.0
# time iteration = 8.272063493728638
# 210
# Data/EN.4.2.2.f.analysis.g10.197707.nc
# 2.0
# time iteration = 8.479175806045532
# 211
# Data/EN.4.2.2.f.analysis.g10.197708.nc
# 1.0
# time iteration = 8.484848737716675
# 212
# Data/EN.4.2.2.f.analysis.g10.197709.nc
# 6.0
# time iteration = 8.663602590560913
# 213
# Data/EN.4.2.2.f.analysis.g10.197710.nc
# 0.0
# time iteration = 8.936947584152222
# 214
# Data/EN.4.2.2.f.analysis.g10.197711.nc
# 2.0
# time iteration = 8.54528260231018
# 215
# Data/EN.4.2.2.f.analysis.g10.197712.nc
# 2.0
# time iteration = 8.158369779586792
# 216
# Data/EN.4.2.2.f.analysis.g10.197801.nc
# 1.0
# time iteration = 8.042554378509521
# 217
# Data/EN.4.2.2.f.analysis.g10.197802.nc
# 0.0
# time iteration = 8.268603086471558
# 218
# Data/EN.4.2.2.f.analysis.g10.197803.nc
# 4.0
# time iteration = 8.29311752319336
# 219
# Data/EN.4.2.2.f.analysis.g10.197804.nc
# 1.0
# time iteration = 9.19388461112976
# 220
# Data/EN.4.2.2.f.analysis.g10.197805.nc
# 0.0
# time iteration = 8.297743558883667
# 221
# Data/EN.4.2.2.f.analysis.g10.197806.nc
# 2.0
# time iteration = 8.29311728477478
# 222
# Data/EN.4.2.2.f.analysis.g10.197807.nc
# 3.0
# time iteration = 8.31526803970337
# 223
# Data/EN.4.2.2.f.analysis.g10.197808.nc
# 0.0
# time iteration = 8.292947053909302
# 224
# Data/EN.4.2.2.f.analysis.g10.197809.nc
# 1.0
# time iteration = 8.149757862091064
# 225
# Data/EN.4.2.2.f.analysis.g10.197810.nc
# 1.0
# time iteration = 8.350812911987305
# 226
# Data/EN.4.2.2.f.analysis.g10.197811.nc
# 2.0
# time iteration = 8.263025999069214
# 227
# Data/EN.4.2.2.f.analysis.g10.197812.nc
# 0.0
# time iteration = 8.578055143356323
# 228
# Data/EN.4.2.2.f.analysis.g10.197901.nc
# 1.0
# time iteration = 8.336958408355713
# 229
# Data/EN.4.2.2.f.analysis.g10.197902.nc
# 1.0
# time iteration = 8.24999451637268
# 230
# Data/EN.4.2.2.f.analysis.g10.197903.nc
# 1.0
# time iteration = 8.243853330612183
# 231
# Data/EN.4.2.2.f.analysis.g10.197904.nc
# 1.0
# time iteration = 1760.2009806632996
# 232
# Data/EN.4.2.2.f.analysis.g10.197905.nc
# 1.0
# time iteration = 10.03335452079773
# 233
# Data/EN.4.2.2.f.analysis.g10.197906.nc
# 0.0
# time iteration = 8.44396162033081
# 234
# Data/EN.4.2.2.f.analysis.g10.197907.nc
# 2.0
# time iteration = 8.425571918487549
# 235
# Data/EN.4.2.2.f.analysis.g10.197908.nc
# 1.0
# time iteration = 8.34122109413147
# 236
# Data/EN.4.2.2.f.analysis.g10.197909.nc
# 1.0
# time iteration = 8.156435251235962
# 237
# Data/EN.4.2.2.f.analysis.g10.197910.nc
# 2.0
# time iteration = 8.211327075958252
# 238
# Data/EN.4.2.2.f.analysis.g10.197911.nc
# 2.0
# time iteration = 8.173587322235107
# 239
# Data/EN.4.2.2.f.analysis.g10.197912.nc
# 3.0
# time iteration = 8.210923910140991
# 240
# Data/EN.4.2.2.f.analysis.g10.198001.nc
# 5.0
# time iteration = 8.377471923828125
# 241
# Data/EN.4.2.2.f.analysis.g10.198002.nc
# 0.0
# time iteration = 8.705121994018555
# 242
# Data/EN.4.2.2.f.analysis.g10.198003.nc
# 1.0
# time iteration = 8.71658730506897
# 243
# Data/EN.4.2.2.f.analysis.g10.198004.nc
# 5.0
# time iteration = 8.34007477760315
# 244
# Data/EN.4.2.2.f.analysis.g10.198005.nc
# 2.0
# time iteration = 8.188779592514038
# 245
# Data/EN.4.2.2.f.analysis.g10.198006.nc
# 1.0
# time iteration = 8.293090581893921
# 246
# Data/EN.4.2.2.f.analysis.g10.198007.nc
# 0.0
# time iteration = 8.113019227981567
# 247
# Data/EN.4.2.2.f.analysis.g10.198008.nc
# 0.0
# time iteration = 8.222409009933472
# 248
# Data/EN.4.2.2.f.analysis.g10.198009.nc
# 2.0
# time iteration = 8.211944341659546
# 249
# Data/EN.4.2.2.f.analysis.g10.198010.nc
# 1.0
# time iteration = 8.126222848892212
# 250
# Data/EN.4.2.2.f.analysis.g10.198011.nc
# 3.0
# time iteration = 8.157444953918457
# 251
# Data/EN.4.2.2.f.analysis.g10.198012.nc
# 5.0
# time iteration = 8.362397909164429
# 252
# Data/EN.4.2.2.f.analysis.g10.198101.nc
# 0.0
# time iteration = 8.26289176940918
# 253
# Data/EN.4.2.2.f.analysis.g10.198102.nc
# 3.0
# time iteration = 8.357302188873291
# 254
# Data/EN.4.2.2.f.analysis.g10.198103.nc
# 0.0
# time iteration = 8.177629947662354
# 255
# Data/EN.4.2.2.f.analysis.g10.198104.nc
# 1.0
# time iteration = 8.189423322677612
# 256
# Data/EN.4.2.2.f.analysis.g10.198105.nc
# 2.0
# time iteration = 8.298925399780273
# 257
# Data/EN.4.2.2.f.analysis.g10.198106.nc
# 1.0
# time iteration = 8.566458702087402
# 258
# Data/EN.4.2.2.f.analysis.g10.198107.nc
# 0.0
# time iteration = 9.693115949630737
# 259
# Data/EN.4.2.2.f.analysis.g10.198108.nc
# 2.0
# time iteration = 8.208888292312622
# 260
# Data/EN.4.2.2.f.analysis.g10.198109.nc
# 3.0
# time iteration = 8.159827947616577
# 261
# Data/EN.4.2.2.f.analysis.g10.198110.nc
# 0.0
# time iteration = 8.116814851760864
# 262
# Data/EN.4.2.2.f.analysis.g10.198111.nc
# 2.0
# time iteration = 8.086402177810669
# 263
# Data/EN.4.2.2.f.analysis.g10.198112.nc
# 3.0
# time iteration = 9.005078554153442
# 264
# Data/EN.4.2.2.f.analysis.g10.198201.nc
# 2.0
# time iteration = 8.310821771621704
# 265
# Data/EN.4.2.2.f.analysis.g10.198202.nc
# 3.0
# time iteration = 8.262401103973389
# 266
# Data/EN.4.2.2.f.analysis.g10.198203.nc
# 1.0
# time iteration = 8.284027576446533
# 267
# Data/EN.4.2.2.f.analysis.g10.198204.nc
# 1.0
# time iteration = 8.416420698165894
# 268
# Data/EN.4.2.2.f.analysis.g10.198205.nc
# 2.0
# time iteration = 8.696085929870605
# 269
# Data/EN.4.2.2.f.analysis.g10.198206.nc
# 0.0
# time iteration = 8.796417951583862
# 270
# Data/EN.4.2.2.f.analysis.g10.198207.nc
# 3.0
# time iteration = 9.338127851486206
# 271
# Data/EN.4.2.2.f.analysis.g10.198208.nc
# 2.0
# time iteration = 8.293733835220337
# 272
# Data/EN.4.2.2.f.analysis.g10.198209.nc
# 3.0
# time iteration = 8.295945167541504
# 273
# Data/EN.4.2.2.f.analysis.g10.198210.nc
# 2.0
# time iteration = 8.211426496505737
# 274
# Data/EN.4.2.2.f.analysis.g10.198211.nc
# 2.0
# time iteration = 8.215113878250122
# 275
# Data/EN.4.2.2.f.analysis.g10.198212.nc
# 2.0
# time iteration = 9.296993017196655
# 276
# Data/EN.4.2.2.f.analysis.g10.198301.nc
# 1.0
# time iteration = 9.251144170761108
# 277
# Data/EN.4.2.2.f.analysis.g10.198302.nc
# 3.0
# time iteration = 8.479872226715088
# 278
# Data/EN.4.2.2.f.analysis.g10.198303.nc
# 0.0
# time iteration = 8.09326982498169
# 279
# Data/EN.4.2.2.f.analysis.g10.198304.nc
# 1.0
# time iteration = 8.059817790985107
# 280
# Data/EN.4.2.2.f.analysis.g10.198305.nc
# 4.0
# time iteration = 8.325198650360107
# 281
# Data/EN.4.2.2.f.analysis.g10.198306.nc
# 0.0
# time iteration = 8.433372974395752
# 282
# Data/EN.4.2.2.f.analysis.g10.198307.nc
# 2.0
# time iteration = 8.413043737411499
# 283
# Data/EN.4.2.2.f.analysis.g10.198308.nc
# 3.0
# time iteration = 8.592423677444458
# 284
# Data/EN.4.2.2.f.analysis.g10.198309.nc
# 1.0
# time iteration = 9.045162677764893
# 285
# Data/EN.4.2.2.f.analysis.g10.198310.nc
# 2.0
# time iteration = 8.678322076797485
# 286
# Data/EN.4.2.2.f.analysis.g10.198311.nc
# 4.0
# time iteration = 8.350167274475098
# 287
# Data/EN.4.2.2.f.analysis.g10.198312.nc
# 1.0
# time iteration = 8.460933208465576
# 288
# Data/EN.4.2.2.f.analysis.g10.198401.nc
# 2.0
# time iteration = 8.551868200302124
# 289
# Data/EN.4.2.2.f.analysis.g10.198402.nc
# 3.0
# time iteration = 8.650754690170288
# 290
# Data/EN.4.2.2.f.analysis.g10.198403.nc
# 0.0
# time iteration = 8.347742557525635
# 291
# Data/EN.4.2.2.f.analysis.g10.198404.nc
# 0.0
# time iteration = 8.708077192306519
# 292
# Data/EN.4.2.2.f.analysis.g10.198405.nc
# 3.0
# time iteration = 8.161258220672607
# 293
# Data/EN.4.2.2.f.analysis.g10.198406.nc
# 0.0
# time iteration = 8.165751218795776
# 294
# Data/EN.4.2.2.f.analysis.g10.198407.nc
# 0.0
# time iteration = 8.058571815490723
# 295
# Data/EN.4.2.2.f.analysis.g10.198408.nc
# 1.0
# time iteration = 8.148452281951904
# 296
# Data/EN.4.2.2.f.analysis.g10.198409.nc
# 2.0
# time iteration = 8.235574960708618
# 297
# Data/EN.4.2.2.f.analysis.g10.198410.nc
# 2.0
# time iteration = 8.14407992362976
# 298
# Data/EN.4.2.2.f.analysis.g10.198411.nc
# 0.0
# time iteration = 8.223705291748047
# 299
# Data/EN.4.2.2.f.analysis.g10.198412.nc
# 3.0
# time iteration = 8.224262237548828
# 300
# Data/EN.4.2.2.f.analysis.g10.198501.nc
# 2.0
# time iteration = 8.220879316329956
# 301
# Data/EN.4.2.2.f.analysis.g10.198502.nc
# 2.0
# time iteration = 8.128498554229736
# 302
# Data/EN.4.2.2.f.analysis.g10.198503.nc

# %%
plt.plot(range(ncounter),APE_mean_time_series-APE_mean_time_series.mean(),linewidth=1,label=f'All Ocean, Mean = {np.round(APE_mean_time_series.mean(),2)}')
plt.plot(range(ncounter),APE_IO_mean_time_series-APE_IO_mean_time_series.mean(),linewidth=1,label=f'Indian Ocean, Mean = {np.round(APE_IO_mean_time_series.mean(),2)}'')
plt.plot(range(ncounter),APE_PO_mean_time_series-APE_PO_mean_time_series.mean(),linewidth=1,label=f'Pacific Ocean, , Mean = {np.round(APE_PO_mean_time_series.mean(),2)}'')
#plt.gca().set_ylim(3.38,3.47)
#plt.gca().invert_yaxis()
plt.legend(loc='best')
plt.ylabel('APE Variation(J/kg)')
plt.xlabel('Time') 
plt.title(ocean)
plt.xticks(np.arange(0, ncounter, 120), labels = np.arange(start_year, end_year+1, 10))
plt.xticks(ticks=np.arange(0, ncounter, 12), labels=None, minor=True)
plt.savefig(f'APE_oceans')

plt.show()

# %%
plt.plot(range(ncounter),CT_mean_time_series,'r',linewidth=1,label='CT')
plt.plot(range(ncounter),PT_mean_time_series,'b',linewidth=1,label='PT')
plt.plot(range(ncounter),CTR_mean_time_series,'g',linewidth=1,label='CTR') 
# plt.gca().set_ylim(3.38,3.47)
#plt.gca().invert_yaxis()
plt.legend(loc='best')
plt.ylabel('Temperature Variation($^\circ C$)')
plt.xlabel('Time') 
# plt.savefig(f'Temp_{')
plt.xticks(np.arange(0, ncounter, 120), labels = np.arange(start_year, end_year+1, 10))
plt.xticks(ticks=np.arange(0, ncounter, 12), labels=None, minor=True)
plt.show()

# %%
plt.plot(range(ncounter),CT_mean_time_series-CT_mean_time_series.mean(),linewidth=1,label='All Ocean')
plt.plot(range(ncounter),CT_IO_mean_time_series-CT_IO_mean_time_series.mean(),linewidth=1,label='Indian Ocean')
plt.plot(range(ncounter),CT_PO_mean_time_series-CT_PO_mean_time_series.mean(),linewidth=1,label='Pacific Ocean')
plt.legend(loc='best')
plt.ylabel('Conservative Temperature Variation($^\circ C$)')
plt.xlabel('Time') 
plt.savefig(f'Temp_oceans')
plt.xticks(np.arange(0, ncounter, 120), labels = np.arange(start_year, end_year+1, 10))
plt.xticks(ticks=np.arange(0, ncounter, 12), labels=None, minor=True)
plt.show()
